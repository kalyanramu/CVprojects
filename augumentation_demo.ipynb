# %% [markdown]
# <a href="https://colab.research.google.com/github/kalyanramu/CVprojects/blob/master/augumentation_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
import numpy as np
import argparse
# Out:
# Using TensorFlow backend.

# %%
image = load_img("jemma.png")
image = img_to_array(image)
image = np.expand_dims(image,axis=0)

# %%
aug = ImageDataGenerator(rotation_range=30, width_shift_range=0.1,height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
                         horizontal_flip=True, fill_mode="nearest")

# %%
#from google.colab import files
#uploaded = files.upload()
# Out:
#      <input type="file" id="files-e56cdff3-6ca7-426f-bdc8-1434e708ffef" name="files[]" multiple disabled />
#      <output id="result-e56cdff3-6ca7-426f-bdc8-1434e708ffef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving jemma.png to jemma.png

# %%
imageGen = aug.flow(image, batch_size=1, save_to_dir= ".",save_prefix="img_", save_format="jpg")
total = 0
for image in imageGen:
  # increment our counter 
  total += 1
  # if we have reached 10 examples, break from the loop
  if total == 10:
    break

# %%
# !ls
# Out:
# aug__0_1543.jpg  aug__0_7215.jpg  img__0_1966.jpg  img__0_8347.jpg
# aug__0_1905.jpg  aug__0_7804.jpg  img__0_4502.jpg  img__0_8481.jpg
# aug__0_2497.jpg  aug__0_7821.jpg  img__0_498.jpg   img__0_9714.jpg
# aug__0_4220.jpg  aug__0_8816.jpg  img__0_520.jpg   jemma.png
# aug__0_4542.jpg  aug__0_9750.jpg  img__0_5480.jpg  sample_data
# aug__0_4826.jpg  img__0_1344.jpg  img__0_8211.jpg

# %%
import matplotlib.pyplot as plt
import cv2
plt_img = cv2.imread("aug__0_1543.jpg")
print(plt_img.shape)
plt.imshow(plt_img)
# Out:
# (375, 500, 3)
